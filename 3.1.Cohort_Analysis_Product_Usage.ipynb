# %% [markdown]
# ### **Cohort Analysis - Usage Frequency**
#
# In this document, we will explore the frequency of usage of Ironhack's students throughout a period of time.
# The main objective of performing such analysis is to discover any patterns that could help making business decisions.
#
# Some potential questions to be answered are the following:
# - Are students using the service less because they are manually reviewed too much?
# - Are there specific months into the journey where students use the service more?
# - Are there any cohorts using the service more worth exploring?

# %%
#We star by importing the required libraries:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Importing the different datasets

cash = pd.read_csv('/home/ubuntu/Ironhack_all/Ironhack_2ndProject/project_dataset/extract - cash request - data analyst.csv')
fees = pd.read_csv('/home/ubuntu/Ironhack_all/Ironhack_2ndProject/project_dataset/extract - fees - data analyst - .csv')

# %% [markdown]
# #### **Performing data checks, cleaning & transformation**
#
# Before starting any analysis, we need to check for data integrity as well as the quality. Appropriate procedures are conducted to fix or repair any missing values.
# Afterwards, a subset is created from the original data to be used for later analyses.

# %%
cash[cash['user_id'].isna()]
#even when the student cancels the account, we can retrieve the user_id from "deleted_id".
#It provides valuable info as some students deleted the account after paying back.
# Out:
#           id  amount      status                     created_at  \
# 7        654   100.0    rejected   2020-02-10 01:11:53.80827+00
# 8       5672   100.0    canceled   2020-06-28 12:06:33.71284+00
# 19       545   100.0    rejected  2020-01-29 13:53:03.343598+00
# 21       613   100.0    rejected  2020-02-05 17:37:56.852948+00
# 25        84   100.0    rejected  2019-12-11 07:30:42.567035+00
# ...      ...     ...         ...                            ...
# 23922  23989    25.0  money_back  2020-10-24 10:22:05.934286+00
# 23925  22913   100.0  money_back  2020-10-21 22:00:18.904317+00
# 23929  22641   100.0  money_back    2020-10-21 00:46:36.5907+00
# 23940  23832    25.0  money_back   2020-10-23 22:56:09.02721+00
# 23966  25243    50.0  money_back   2020-10-27 14:41:25.73491+00
#
#                           updated_at  user_id                   moderated_at  \
# 7      2020-02-10 11:53:32.104131+00      NaN  2020-02-10 09:11:21.350695+00
# 8      2020-06-28 12:06:33.712853+00      NaN                            NaN
# 19     2020-02-08 06:21:16.156719+00      NaN  2020-01-29 14:39:11.563872+00
# 21      2020-02-08 06:21:16.15229+00      NaN  2020-02-06 12:48:09.880702+00
# 25     2020-01-10 16:58:06.837117+00      NaN  2020-01-10 16:58:06.830329+00
# ...                              ...      ...                            ...
# 23922  2020-12-18 13:14:25.891447+00      NaN                            NaN
# 23925  2020-12-18 13:11:15.976246+00      NaN                            NaN
# 23929  2020-12-18 13:15:45.384787+00      NaN                            NaN
# 23940  2020-12-18 13:11:28.776102+00      NaN                            NaN
# 23966  2020-12-18 13:15:40.843946+00      NaN                            NaN
#
#        deleted_account_id             reimbursement_date  \
# 7                   309.0   2020-03-11 01:11:53.80793+00
# 8                  2499.0         2020-07-07 22:00:00+00
# 19                  304.0  2020-02-28 13:53:03.343216+00
# 21                  304.0  2020-03-08 17:37:56.842421+00
# 25                   91.0  2020-01-10 07:30:42.567035+00
# ...                   ...                            ...
# 23922             29610.0  2020-11-03 10:22:40.194197+00
# 23925             30404.0         2020-11-09 23:51:00+00
# 23929             29911.0         2020-12-06 23:00:00+00
# 23940             29803.0         2020-12-04 23:00:00+00
# 23966             30367.0         2020-11-03 22:00:00+00
#
#       cash_request_received_date                money_back_date transfer_type  \
# 7                            NaN                            NaN       regular
# 8                            NaN                            NaN       regular
# 19                           NaN                            NaN       regular
# 21                           NaN                            NaN       regular
# 25                           NaN                            NaN       regular
# ...                          ...                            ...           ...
# 23922                        NaN  2020-11-16 02:57:54.235926+00       instant
# 23925                 2020-10-23  2020-11-10 19:51:45.285165+00       instant
# 23929                 2020-10-22         2020-12-10 23:00:00+00       instant
# 23940                 2020-10-24         2020-12-08 23:00:00+00       instant
# 23966                 2020-10-28  2020-12-01 13:26:53.787672+00       instant
#
#                              send_at recovery_status  \
# 7                                NaN             NaN
# 8                                NaN             NaN
# 19                               NaN             NaN
# 21                               NaN             NaN
# 25                               NaN             NaN
# ...                              ...             ...
# 23922  2020-10-24 10:22:40.194197+00       completed
# 23925  2020-10-21 22:00:45.462413+00             NaN
# 23929  2020-10-21 00:47:58.826568+00             NaN
# 23940  2020-10-23 22:56:42.839064+00             NaN
# 23966  2020-10-27 14:41:57.901946+00       completed
#
#                        reco_creation               reco_last_update
# 7                                NaN                            NaN
# 8                                NaN                            NaN
# 19                               NaN                            NaN
# 21                               NaN                            NaN
# 25                               NaN                            NaN
# ...                              ...                            ...
# 23922   2020-11-13 22:40:42.99552+00  2020-11-16 02:57:54.252045+00
# 23925                            NaN                            NaN
# 23929                            NaN                            NaN
# 23940                            NaN                            NaN
# 23966  2020-11-12 23:20:41.928788+00  2020-12-01 13:26:53.815504+00
#
# [2103 rows x 16 columns]

# %%
#Creating a subset with the necessary columns only
cash_cohort = cash[['id','user_id','created_at','deleted_account_id','recovery_status']]


#Filling missing user_ids using deleted_account_id
cash_cohort['user_id'] = cash_cohort['user_id'].fillna(cash_cohort['deleted_account_id'])

#Make sure no more missing user_ids
cash_cohort[cash_cohort['user_id'].isna()]
# Out:
# /tmp/ipykernel_762/4044134743.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cash_cohort['user_id'] = cash_cohort['user_id'].fillna(cash_cohort['deleted_account_id'])
# Empty DataFrame
# Columns: [id, user_id, created_at, deleted_account_id, recovery_status]
# Index: []

# %%
#Dropping deleted_account_id because I no longer need it:
cash_cohort = cash_cohort.drop('deleted_account_id', axis='columns')
cash_cohort.head(1)
# Out:
#    id  user_id                     created_at recovery_status
# 0   5    804.0  2019-12-10 19:05:21.596873+00             NaN

# %% [markdown]
# #### **Cohort Analysis**
#
# In this section, we will define the variable/column on which the cohort will be based. In this case, minimum cash request date is taken as the cohort group. The analysis will essentially be looking at the people that created a cash request, how much % of the same people keep using repeatedly the service.

# %%
#I'm transforming the "created_at" to datetime for manipulation afterwards
cash_cohort['created_at'] = pd.to_datetime(cash_cohort['created_at'])


cash_cohort['cohort group'] = cash_cohort.groupby('user_id')['created_at'].transform('min').dt.to_period('M') #Getting the minimum date from each unique person, and getting YYYY-MM
cash_cohort['usage date'] = cash_cohort['created_at'].dt.to_period('M')  #Getting the dates they make cash request in YYYY-MM too (as they can make as many as they want)

#Calculating how many months have passed between creation date and another cash request. If they're the same, it will be 0
cash_cohort['Passed months'] = (cash_cohort['usage date'].dt.year - cash_cohort['cohort group'].dt.year)*12 + cash_cohort['usage date'].dt.month - cash_cohort['cohort group'].dt.month

cash_cohort
# Out:
# /tmp/ipykernel_762/3408187512.py:5: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   cash_cohort['cohort group'] = cash_cohort.groupby('user_id')['created_at'].transform('min').dt.to_period('M') #Getting the minimum date from each unique person, and getting YYYY-MM
# /tmp/ipykernel_762/3408187512.py:6: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   cash_cohort['usage date'] = cash_cohort['created_at'].dt.to_period('M')  #Getting the dates they make cash request in YYYY-MM too (as they can make as many as they want)
#           id  user_id                       created_at recovery_status  \
# 0          5    804.0 2019-12-10 19:05:21.596873+00:00             NaN
# 1         70    231.0 2019-12-10 19:50:12.347780+00:00             NaN
# 2          7    191.0 2019-12-10 19:13:35.825460+00:00             NaN
# 3         10    761.0 2019-12-10 19:16:10.880172+00:00             NaN
# 4       1594   7686.0 2020-05-06 09:59:38.877376+00:00             NaN
# ...      ...      ...                              ...             ...
# 23965  20616  13681.0 2020-10-12 13:54:11.686225+00:00             NaN
# 23966  25243  30367.0 2020-10-27 14:41:25.734910+00:00       completed
# 23967  22357  82122.0 2020-10-20 07:58:04.006937+00:00             NaN
# 23968  20256  64517.0 2020-10-10 05:40:55.700422+00:00             NaN
# 23969  19886  44867.0 2020-10-08 14:16:52.155661+00:00             NaN
#
#       cohort group usage date  Passed months
# 0          2019-12    2019-12              0
# 1          2019-12    2019-12              0
# 2          2019-12    2019-12              0
# 3          2019-12    2019-12              0
# 4          2020-05    2020-05              0
# ...            ...        ...            ...
# 23965      2020-06    2020-10              4
# 23966      2020-10    2020-10              0
# 23967      2020-10    2020-10              0
# 23968      2020-10    2020-10              0
# 23969      2020-09    2020-10              1
#
# [23970 rows x 7 columns]

# %%
cash_cohort[cash_cohort['user_id']==13681.0] #Checking a random user to see that in fact this user has more than 1 CR
# Out:
#           id  user_id                       created_at recovery_status  \
# 13997   2771  13681.0 2020-06-09 11:55:34.299738+00:00       completed
# 23965  20616  13681.0 2020-10-12 13:54:11.686225+00:00             NaN
#
#       cohort group usage date  Passed months
# 13997      2020-06    2020-06              0
# 23965      2020-06    2020-10              4

# %%
groupped_cohort = cash_cohort.groupby(['cohort group', 'Passed months'])['user_id'].nunique().reset_index()

#I'm groupping by cohort, and passed months and then I'm trying to see how many unique users have made cash request.

cohort_pivot = groupped_cohort.pivot(index='cohort group', columns='Passed months', values='user_id') #Pivoting the group by

Initial_users = cohort_pivot[0] 
#I'm extracting this column because I want to know the number total students by cohort group. 
#So later we can compare the % of students from the total that made another cash request
Initial_users
# Out:
# cohort group
# 2019-11       1.0
# 2019-12     254.0
# 2020-01     106.0
# 2020-02      90.0
# 2020-03      86.0
# 2020-04     246.0
# 2020-05     432.0
# 2020-06    1540.0
# 2020-07    1482.0
# 2020-08     728.0
# 2020-09    1950.0
# 2020-10    4802.0
# 2020-11      76.0
# Freq: M, Name: 0, dtype: float64

# %%
cohort_graph = cohort_pivot.divide(cohort_pivot.iloc[:, 0], axis=0) # Storing a version for graph later (it will deal with NAns automatically and put %)
cohort_pivot_n = cohort_pivot.divide(cohort_pivot.iloc[:, 0], axis=0) * 100 #This is for the table, so I have to multiply by 100 to get % scale

# %%
cohort_pivot_n.iloc[0] = cohort_pivot.iloc[0].fillna(0) #filling specific spots with 0 to differentiate actual 0s to no data yet  
cohort_pivot_n.loc['2020-02',9] = 0
cohort_pivot_n.loc['2020-04',7] = 0

cohort_graph.iloc[0] = cohort_pivot.iloc[0].fillna(0) #filling specific spots with 0 to differentiate actual 0s to no data yet  
cohort_graph.loc['2020-02',9] = 0
cohort_graph.loc['2020-04',7] = 0

cohort_pivot_n
# Out:
# Passed months     0          1          2          3          4          5   \
# cohort group
# 2019-11          1.0   1.000000   0.000000   0.000000   0.000000   1.000000
# 2019-12        100.0  35.433071  22.834646  26.771654  26.377953  29.527559
# 2020-01        100.0  20.754717  15.094340  25.471698  25.471698  25.471698
# 2020-02        100.0  50.000000  46.666667  46.666667  43.333333  43.333333
# 2020-03        100.0  44.186047  43.023256  52.325581  41.860465  39.534884
# 2020-04        100.0  47.154472  49.593496  37.398374  32.520325  30.894309
# 2020-05        100.0  59.027778  50.694444  43.055556  34.027778  35.648148
# 2020-06        100.0  49.090909  48.246753  37.272727  36.753247   0.324675
# 2020-07        100.0  47.435897  34.480432  35.964912   0.472335        NaN
# 2020-08        100.0  40.247253  33.928571   1.373626        NaN        NaN
# 2020-09        100.0  34.871795   1.025641        NaN        NaN        NaN
# 2020-10        100.0   0.312370        NaN        NaN        NaN        NaN
# 2020-11        100.0        NaN        NaN        NaN        NaN        NaN
#
# Passed months         6          7          8          9          10        11
# cohort group
# 2019-11         1.000000   0.000000   0.000000   1.000000   1.000000  1.000000
# 2019-12        28.740157  23.228346  26.377953  16.929134  24.409449  0.393701
# 2020-01        26.415094  19.811321  18.867925  22.641509   0.943396       NaN
# 2020-02        40.000000  27.777778  37.777778   0.000000        NaN       NaN
# 2020-03        33.720930  31.395349   1.162791        NaN        NaN       NaN
# 2020-04        24.796748   0.000000        NaN        NaN        NaN       NaN
# 2020-05         0.925926        NaN        NaN        NaN        NaN       NaN
# 2020-06              NaN        NaN        NaN        NaN        NaN       NaN
# 2020-07              NaN        NaN        NaN        NaN        NaN       NaN
# 2020-08              NaN        NaN        NaN        NaN        NaN       NaN
# 2020-09              NaN        NaN        NaN        NaN        NaN       NaN
# 2020-10              NaN        NaN        NaN        NaN        NaN       NaN
# 2020-11              NaN        NaN        NaN        NaN        NaN       NaN

# %%
cohort_graph
# Out:
# Passed months   0         1         2         3         4         5   \
# cohort group
# 2019-11        1.0  1.000000  0.000000  0.000000  0.000000  1.000000
# 2019-12        1.0  0.354331  0.228346  0.267717  0.263780  0.295276
# 2020-01        1.0  0.207547  0.150943  0.254717  0.254717  0.254717
# 2020-02        1.0  0.500000  0.466667  0.466667  0.433333  0.433333
# 2020-03        1.0  0.441860  0.430233  0.523256  0.418605  0.395349
# 2020-04        1.0  0.471545  0.495935  0.373984  0.325203  0.308943
# 2020-05        1.0  0.590278  0.506944  0.430556  0.340278  0.356481
# 2020-06        1.0  0.490909  0.482468  0.372727  0.367532  0.003247
# 2020-07        1.0  0.474359  0.344804  0.359649  0.004723       NaN
# 2020-08        1.0  0.402473  0.339286  0.013736       NaN       NaN
# 2020-09        1.0  0.348718  0.010256       NaN       NaN       NaN
# 2020-10        1.0  0.003124       NaN       NaN       NaN       NaN
# 2020-11        1.0       NaN       NaN       NaN       NaN       NaN
#
# Passed months        6         7         8         9         10        11
# cohort group
# 2019-11        1.000000  0.000000  0.000000  1.000000  1.000000  1.000000
# 2019-12        0.287402  0.232283  0.263780  0.169291  0.244094  0.003937
# 2020-01        0.264151  0.198113  0.188679  0.226415  0.009434       NaN
# 2020-02        0.400000  0.277778  0.377778  0.000000       NaN       NaN
# 2020-03        0.337209  0.313953  0.011628       NaN       NaN       NaN
# 2020-04        0.247967  0.000000       NaN       NaN       NaN       NaN
# 2020-05        0.009259       NaN       NaN       NaN       NaN       NaN
# 2020-06             NaN       NaN       NaN       NaN       NaN       NaN
# 2020-07             NaN       NaN       NaN       NaN       NaN       NaN
# 2020-08             NaN       NaN       NaN       NaN       NaN       NaN
# 2020-09             NaN       NaN       NaN       NaN       NaN       NaN
# 2020-10             NaN       NaN       NaN       NaN       NaN       NaN
# 2020-11             NaN       NaN       NaN       NaN       NaN       NaN

# %%
cohort_pivot_n = cohort_pivot_n.applymap(lambda x: '{:.2f}%'.format(x) if pd.notna(x) else '' ) #Applying a lambda function to get every single number in % format

cohort_pivot_n
# Out:
# /tmp/ipykernel_762/824086306.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   cohort_pivot_n = cohort_pivot_n.applymap(lambda x: '{:.2f}%'.format(x) if pd.notna(x) else '' ) #Applying a lambda function to get every single number in % format
# Passed months       0       1       2       3       4       5       6   \
# cohort group
# 2019-11          1.00%   1.00%   0.00%   0.00%   0.00%   1.00%   1.00%
# 2019-12        100.00%  35.43%  22.83%  26.77%  26.38%  29.53%  28.74%
# 2020-01        100.00%  20.75%  15.09%  25.47%  25.47%  25.47%  26.42%
# 2020-02        100.00%  50.00%  46.67%  46.67%  43.33%  43.33%  40.00%
# 2020-03        100.00%  44.19%  43.02%  52.33%  41.86%  39.53%  33.72%
# 2020-04        100.00%  47.15%  49.59%  37.40%  32.52%  30.89%  24.80%
# 2020-05        100.00%  59.03%  50.69%  43.06%  34.03%  35.65%   0.93%
# 2020-06        100.00%  49.09%  48.25%  37.27%  36.75%   0.32%
# 2020-07        100.00%  47.44%  34.48%  35.96%   0.47%
# 2020-08        100.00%  40.25%  33.93%   1.37%
# 2020-09        100.00%  34.87%   1.03%
# 2020-10        100.00%   0.31%
# 2020-11        100.00%
#
# Passed months      7       8       9       10     11
# cohort group
# 2019-11         0.00%   0.00%   1.00%   1.00%  1.00%
# 2019-12        23.23%  26.38%  16.93%  24.41%  0.39%
# 2020-01        19.81%  18.87%  22.64%   0.94%
# 2020-02        27.78%  37.78%   0.00%
# 2020-03        31.40%   1.16%
# 2020-04         0.00%
# 2020-05
# 2020-06
# 2020-07
# 2020-08
# 2020-09
# 2020-10
# 2020-11

# %%
cohort_pivot_n.insert(0,'Total_users', Initial_users) #As mentioned in line[9], I'm inserting total users to see the number of students by cohort-group
cohort_pivot_n
# Out:
# Passed months  Total_users        0       1       2       3       4       5  \
# cohort group
# 2019-11                1.0    1.00%   1.00%   0.00%   0.00%   0.00%   1.00%
# 2019-12              254.0  100.00%  35.43%  22.83%  26.77%  26.38%  29.53%
# 2020-01              106.0  100.00%  20.75%  15.09%  25.47%  25.47%  25.47%
# 2020-02               90.0  100.00%  50.00%  46.67%  46.67%  43.33%  43.33%
# 2020-03               86.0  100.00%  44.19%  43.02%  52.33%  41.86%  39.53%
# 2020-04              246.0  100.00%  47.15%  49.59%  37.40%  32.52%  30.89%
# 2020-05              432.0  100.00%  59.03%  50.69%  43.06%  34.03%  35.65%
# 2020-06             1540.0  100.00%  49.09%  48.25%  37.27%  36.75%   0.32%
# 2020-07             1482.0  100.00%  47.44%  34.48%  35.96%   0.47%
# 2020-08              728.0  100.00%  40.25%  33.93%   1.37%
# 2020-09             1950.0  100.00%  34.87%   1.03%
# 2020-10             4802.0  100.00%   0.31%
# 2020-11               76.0  100.00%
#
# Passed months       6       7       8       9      10     11
# cohort group
# 2019-11         1.00%   0.00%   0.00%   1.00%   1.00%  1.00%
# 2019-12        28.74%  23.23%  26.38%  16.93%  24.41%  0.39%
# 2020-01        26.42%  19.81%  18.87%  22.64%   0.94%
# 2020-02        40.00%  27.78%  37.78%   0.00%
# 2020-03        33.72%  31.40%   1.16%
# 2020-04        24.80%   0.00%
# 2020-05         0.93%
# 2020-06
# 2020-07
# 2020-08
# 2020-09
# 2020-10
# 2020-11

# %%
with sns.axes_style("white"):
    fig, ax = plt.subplots(1, 2, figsize=(12, 8), sharey=True, gridspec_kw={'width_ratios': [1, 11]})
    
    # cohort_graph heatmap itself
    sns.heatmap(cohort_graph, 
                mask=cohort_graph.isnull(), 
                annot=True, 
                fmt='.0%', 
                cmap='RdYlGn', 
                ax=ax[1])
    ax[1].set_title('Monthly Cohorts: Usage Frequency', fontsize=16)
    ax[1].set(xlabel='# of periods',
              ylabel='')

    # This is where I include the total number of users so we have it in the graph as well
    cohort_size_df = pd.DataFrame(Initial_users).rename(columns={0: 'Months passed'})
    white_cmap = mcolors.ListedColormap(['white'])
    sns.heatmap(cohort_size_df, 
                annot=True, 
                cbar=False, 
                fmt='g', 
                cmap=white_cmap, 
                ax=ax[0])

    fig.tight_layout()

# %% [markdown]
# #### **Cohort Analysis - Interpretation**
#
# 1) The first cohort(2019-11) doesn't provide much valuable info as the whole cohort is just one person, so we will disregard this cohort group.
#
# 2) Cohort '2020-05' has the best % of usage frequency after its creation month.
#
# 3) We can see that the first two cohorts have not so great retention/frequency usage rate as the % is always in the 20s after the first created month. In comparison, we see an improvement in the cohort '2020-02' and onwards. Therefore, a quick analysis is done to check whether manual review of cash request(indicated by the rows where moderated_at is not null) impacts the % of retention. A comparison is done between cohorts from '2019-12' to '2020-05'

# %%
deep_cohort = cash[['id','user_id','created_at','deleted_account_id','recovery_status','moderated_at', 'status', 'transfer_type']] #selecting again the specific columns needed
deep_cohort['user_id'] = deep_cohort['user_id'].fillna(deep_cohort['deleted_account_id']) #filling the missing user_ids for deleted_account_ids
deep_cohort['moderated_at'] = deep_cohort['moderated_at'].isna() #Changing the column to boolen "True" or "False" (check if it is blank) as blank means no manual review

#The following code is used to create the cohort again
deep_cohort['created_at'] = pd.to_datetime(deep_cohort['created_at'])
deep_cohort['usage date'] = deep_cohort['created_at'].dt.to_period('M')

deep_cohort['cohort'] = deep_cohort.groupby('user_id')['created_at'].transform('min').dt.to_period('M')

deep_cohort
# Out:
# /tmp/ipykernel_762/1007605566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deep_cohort['user_id'] = deep_cohort['user_id'].fillna(deep_cohort['deleted_account_id'])
# /tmp/ipykernel_762/1007605566.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deep_cohort['moderated_at'] = deep_cohort['moderated_at'].isna()
# /tmp/ipykernel_762/1007605566.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deep_cohort['created_at'] = pd.to_datetime(deep_cohort['created_at'])
# /tmp/ipykernel_762/1007605566.py:5: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   deep_cohort['usage date'] = deep_cohort['created_at'].dt.to_period('M')
# /tmp/ipykernel_762/1007605566.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deep_cohort['usage date'] = deep_cohort['created_at'].dt.to_period('M')
# /tmp/ipykernel_762/1007605566.py:7: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   deep_cohort['cohort'] = deep_cohort.groupby('user_id')['created_at'].transform('min').dt.to_period('M')
# /tmp/ipykernel_762/1007605566.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deep_cohort['cohort'] = deep_cohort.groupby('user_id')['created_at'].transform('min').dt.to_period('M')
#           id  user_id                       created_at  deleted_account_id  \
# 0          5    804.0 2019-12-10 19:05:21.596873+00:00                 NaN
# 1         70    231.0 2019-12-10 19:50:12.347780+00:00                 NaN
# 2          7    191.0 2019-12-10 19:13:35.825460+00:00                 NaN
# 3         10    761.0 2019-12-10 19:16:10.880172+00:00                 NaN
# 4       1594   7686.0 2020-05-06 09:59:38.877376+00:00                 NaN
# ...      ...      ...                              ...                 ...
# 23965  20616  13681.0 2020-10-12 13:54:11.686225+00:00                 NaN
# 23966  25243  30367.0 2020-10-27 14:41:25.734910+00:00             30367.0
# 23967  22357  82122.0 2020-10-20 07:58:04.006937+00:00                 NaN
# 23968  20256  64517.0 2020-10-10 05:40:55.700422+00:00                 NaN
# 23969  19886  44867.0 2020-10-08 14:16:52.155661+00:00                 NaN
#
#       recovery_status  moderated_at             status transfer_type  \
# 0                 NaN         False           rejected       regular
# 1                 NaN         False           rejected       regular
# 2                 NaN         False           rejected       regular
# 3                 NaN         False           rejected       regular
# 4                 NaN         False           rejected       regular
# ...               ...           ...                ...           ...
# 23965             NaN          True         money_back       instant
# 23966       completed          True         money_back       instant
# 23967             NaN          True         money_back       instant
# 23968             NaN          True         money_back       instant
# 23969             NaN          True  direct_debit_sent       instant
#
#       usage date   cohort
# 0        2019-12  2019-12
# 1        2019-12  2019-12
# 2        2019-12  2019-12
# 3        2019-12  2019-12
# 4        2020-05  2020-05
# ...          ...      ...
# 23965    2020-10  2020-06
# 23966    2020-10  2020-10
# 23967    2020-10  2020-10
# 23968    2020-10  2020-10
# 23969    2020-10  2020-09
#
# [23970 rows x 10 columns]

# %%
#This code is to select only the cohorts I want to compare
deep_cohort = deep_cohort[(deep_cohort['cohort'] == '2019-12') |
                          (deep_cohort['cohort'] == '2020-01') | 
                          (deep_cohort['cohort'] == '2020-02') | 
                          (deep_cohort['cohort'] == '2020-03') | 
                          (deep_cohort['cohort'] == '2020-04') | 
                          (deep_cohort['cohort'] == '2020-05')]

#Code 1 to create a groupped subset to analyze differences between manual reviewed requests and those not reviewed
deep_manual = deep_cohort.groupby(['cohort','moderated_at'])['user_id'].count().reset_index() 

#Code 2 to create a groupped subset to analyze differences between different status
deep_status = deep_cohort.groupby(['cohort','status'])['user_id'].count().reset_index()

#Code 3 to create a groupped subset to analyze differences between different transfer types
deep_transfer = deep_cohort.groupby(['cohort','transfer_type'])['user_id'].count().reset_index()

deep_status
# Out:
#      cohort                 status  user_id
# 0   2019-12               canceled        1
# 1   2019-12  direct_debit_rejected       41
# 2   2019-12      direct_debit_sent        2
# 3   2019-12             money_back      690
# 4   2019-12               rejected      345
# 5   2019-12   transaction_declined        1
# 6   2020-01  direct_debit_rejected       11
# 7   2020-01             money_back      215
# 8   2020-01               rejected      128
# 9   2020-02                 active        1
# 10  2020-02  direct_debit_rejected        8
# 11  2020-02             money_back      330
# 12  2020-02               rejected      101
# 13  2020-02   transaction_declined        1
# 14  2020-03                 active        1
# 15  2020-03  direct_debit_rejected        4
# 16  2020-03      direct_debit_sent        1
# 17  2020-03             money_back      277
# 18  2020-03               rejected       88
# 19  2020-04  direct_debit_rejected       34
# 20  2020-04      direct_debit_sent        1
# 21  2020-04             money_back      642
# 22  2020-04               rejected      275
# 23  2020-05                 active        1
# 24  2020-05               canceled        1
# 25  2020-05  direct_debit_rejected       41
# 26  2020-05      direct_debit_sent        2
# 27  2020-05             money_back     1192
# 28  2020-05               rejected      423

# %%
deep_manual['total_count'] = deep_manual.groupby(['cohort'])['user_id'].transform('sum')

deep_manual['percentage'] = deep_manual['user_id']/deep_manual['total_count']*100

deep_group = deep_manual.rename(columns={'user_id': 'count of manual reviews', 'total_count' : 'total'})

deep_group
# Out:
#      cohort  moderated_at  count of manual reviews  total  percentage
# 0   2019-12         False                     1030   1080   95.370370
# 1   2019-12          True                       50   1080    4.629630
# 2   2020-01         False                      325    354   91.807910
# 3   2020-01          True                       29    354    8.192090
# 4   2020-02         False                      397    441   90.022676
# 5   2020-02          True                       44    441    9.977324
# 6   2020-03         False                      331    371   89.218329
# 7   2020-03          True                       40    371   10.781671
# 8   2020-04         False                      881    952   92.542017
# 9   2020-04          True                       71    952    7.457983
# 10  2020-05         False                     1479   1660   89.096386
# 11  2020-05          True                      181   1660   10.903614

# %%
deep_status['total_count'] = deep_status.groupby(['cohort'])['user_id'].transform('sum')

deep_status['percentage'] = deep_status['user_id']/deep_status['total_count']*100


deep_group2_pivot = deep_status.pivot(index='cohort', columns = 'status', values = 'percentage')

deep_group2_pivot
# Out:
# status     active  canceled  direct_debit_rejected  direct_debit_sent  \
# cohort
# 2019-12       NaN  0.092593               3.796296           0.185185
# 2020-01       NaN       NaN               3.107345                NaN
# 2020-02  0.226757       NaN               1.814059                NaN
# 2020-03  0.269542       NaN               1.078167           0.269542
# 2020-04       NaN       NaN               3.571429           0.105042
# 2020-05  0.060241  0.060241               2.469880           0.120482
#
# status   money_back   rejected  transaction_declined
# cohort
# 2019-12   63.888889  31.944444              0.092593
# 2020-01   60.734463  36.158192                   NaN
# 2020-02   74.829932  22.902494              0.226757
# 2020-03   74.663073  23.719677                   NaN
# 2020-04   67.436975  28.886555                   NaN
# 2020-05   71.807229  25.481928                   NaN

# %%
plt.figure(figsize=(10,6))

deep_group2_pivot.plot(kind='line', marker='o', ax=plt.gca())

plt.title('Percentage of Cash Requests per Status and Cohort')
plt.xlabel('Cohort')
plt.ylabel('Percentage per status')
plt.xticks(rotation=0)
plt.legend(title = 'Status of CR')

plt.show()

# %%
deep_transfer
# Out:
#      cohort transfer_type  user_id
# 0   2019-12       instant      170
# 1   2019-12       regular      910
# 2   2020-01       instant       60
# 3   2020-01       regular      294
# 4   2020-02       instant       84
# 5   2020-02       regular      357
# 6   2020-03       instant       80
# 7   2020-03       regular      291
# 8   2020-04       instant      207
# 9   2020-04       regular      745
# 10  2020-05       instant      496
# 11  2020-05       regular     1164

# %%
deep_transfer['total_count'] = deep_transfer.groupby(['cohort'])['user_id'].transform('sum')

deep_transfer['percentage'] = deep_transfer['user_id']/deep_transfer['total_count']*100

deep_transfer_pivot = deep_transfer.pivot(index='cohort', columns='transfer_type', values='percentage')

deep_transfer_pivot
# Out:
# transfer_type    instant    regular
# cohort
# 2019-12        15.740741  84.259259
# 2020-01        16.949153  83.050847
# 2020-02        19.047619  80.952381
# 2020-03        21.563342  78.436658
# 2020-04        21.743697  78.256303
# 2020-05        29.879518  70.120482

# %%
plt.figure(figsize=(10,6))

deep_transfer_pivot.plot(kind= 'bar', ax=plt.gca())

plt.title('Percentage of Cash Requests per Transfer type and Cohort')
plt.xlabel('Cohort')
plt.ylabel('Percentage per status')
plt.xticks(rotation=0)
plt.legend(title = 'Transfer type')

plt.show()

# %% [markdown]
# From our analysis, we can see:
# 1) That the drop in usage frequency can't really be atributted to whether the request has been reviewed manually or not. The initial hypothesis was that maybe if a cohort group has had many manual reviews, then the usage frequency will drop. From the numbers it doesn't seem to matter as the % of manual reviews between a cohort that has great retention and a cohort that doesn't, does not vary too much
#
# 2) We see that cohort groups where retention is great (e.g: '2020-02' or '2020-03') have more people within the status "money back" and fewer people in "rejected". This could suggest that if the journey is successful (no rejects, and student successfully pays back), then the satisfaction is great prompting them to come back and use the service in the future.
#
# 3) Lastly, we see that request for regular payments have been decreasing over cohort-groups, and coincidentally, the retention rate seems to be higher. This could potentially indicate an area to focus on.
